# %% [markdown]
# <a href="https://colab.research.google.com/github/Nagendra061192/genaihindi/blob/main/FAIIS_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install langchain
# !pip install pypdf
# !pip install sentence-transformers==2.2.2
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.1/809.1 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.9/260.9 kB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 41.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 55.0 MB/s eta 0:00:00
# ...

# %%
# !pip install openai
# !pip install tiktoken
# !pip install faiss-cpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 37.4 MB/s eta 0:00:00
# ...

# %%
# !mkdir pdfs

# %%
from langchain.document_loaders import PyPDFDirectoryLoader

# %%
loader=PyPDFDirectoryLoader("pdfs")
data=loader.load()

# %%
data
# Out:
# [Document(page_content='Prices and Inflation\nInflation in the country continued to moderate during 2017-18. CPI based headline inflation \naveraged 3.3 per cent during April-December 2017-18, the lowest in the last six financial \nyears. The significant reduction in food inflation, particularly of  pulses and vegetables, \nmoderated the general inflation. The average food inflation fell to 1.2 per cent during April-\nDecember 2017-18. Core inflation too declined during this period. Many States witnessed \nreduction in inflation across rural as well as urban areas during the year.      04\nCHAPTER\nINTRODUCTION\n4.1 The economy witnessed a gradual \ntransition from a period of  high and variable \ninflation to more stable prices in the last four \nyears. Headline inflation measured by the \nConsumer Price Index (CPI) has remained under \ncontrol for the fourth successive year. Financial \nyear (FY) 2017-18 began with an annual inflation \nrate of  3.0 per cent. In the first two quart
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter ( chunk_size=500 , chunk_overlap=20 )
text_chunks= text_splitter.split_documents(data)

# %%
len(text_chunks)
# Out:
# 65

# %%
text_chunks[2]
# Out:
# Document(page_content='FY 2017-18, there was a moderate increase in \nprices, resulting in a low level of  inflation of  2.2 \nper cent in quarter one and 3.0 per cent in quarter \ntwo. Headline inflation rate reached its series low of  1.5 per cent in the month of  June 2017. Food \ninflation measured by the Consumer Food Price \nIndex (CFPI) declined to a low of  1.2 per cent \nduring the FY 2017-18 (April-December).\n4.2 The average inflation based on the new \nseries (2011-12) of  Wholesale Price Index (WPI)', metadata={'source': 'pdfs/056-067_Chapter_04_Economic_Survey_2017-18.pdf', 'page': 0})

# %%
from langchain.embeddings import HuggingFaceEmbeddings

# %%
embeddings= HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# ...

# %%
from langchain.vectorstores import FAISS

# %%
vectorstore= FAISS.from_documents(text_chunks, embeddings)

# %%
query="what is corelation"

# %%
docs = vectorstore.similarity_search(query, k=3)

# %%
docs
# Out:
# [Document(page_content='has remained above 4 per cent during the last \nfour financial years. However, it has declined \nfrom 4.8 per cent in FY 2016-17 (Apr-Dec) \nto 4.5 per cent in FY 2017-18 (Apr- Dec) and \nwas 5.2 per cent in December, 2017 (Figure 2). \nRefined core2  is moving very close to core since \nthe beginning of  FY 2017-18, it declined to 4.4 \nper cent in FY 2017-18 (Apr- Dec) from 5.0  per cent in FY 2016-17 (Apr- Dec). Movements of  \nrefined core (excluding housing)3  track the refined', metadata={'source': 'pdfs/056-067_Chapter_04_Economic_Survey_2017-18.pdf', 'page': 2}),
# ...

# %%
len(docs)
# Out:
# 3

# %%
from google.colab import userdata
OPENAI_API_KEY = userdata.get("OPENAI_API_KEY")

# %%
import os
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from langchain.llms import OpenAI

# %%
llm = OpenAI()

# %%
from langchain.chains import RetrievalQA

# %%
qa= RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever= vectorstore.as_retriever())

# %%
query="what is corelation"

# %%
print(qa.run(query))
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-46-260aa8d7cbf0> in <cell line: 1>()
# ----> 1 print(qa.run(query))
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     543             if len(args) != 1:
#     544                 raise ValueError("`run` supports only one positional argument.")
# --> 545             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     546                 _output_key
# ...
